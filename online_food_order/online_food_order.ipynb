# %%
# %pip install pandas
# %pip install matplotlib
# %pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 9.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 10.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 7.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 6.0 MB/s eta 0:00:000:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 4.4 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 1.6 MB/s eta 0:00:005 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("onlinefoods.csv")
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
gender_counts = df["Gender"].value_counts()
gender_percentage = (gender_counts / gender_counts.sum() * 100).round(2)

# %%
print("Gender count:")
print(gender_counts)
print("\nGender percentage:")
print(gender_percentage)
gender_percentage.plot(kind="bar", color=["blue", "pink"], width=0.2)

plt.title("Gender percentage")
plt.xlabel("Gender")
plt.ylabel("percentage (%)")
plt.xticks(rotation=0)

plt.show()
# Out:
# Gender count:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 print("Gender count:")
# ----> 2 print(gender_counts)
#       3 print("\nGender percentage:")
#       4 print(gender_percentage)
#
# NameError: name 'gender_counts' is not defined

# %%
marital_status_counts = df["Marital Status"].value_counts()
marital_status_percentage = (marital_status_counts / marital_status_counts.sum() * 100).round(2)
print("Marital Status count:")
print(marital_status_counts)
print("\nMarital Status percentage:")
print(marital_status_percentage)
marital_status_percentage.plot(kind="bar", color=["blue", "red", "grey"], width=0.2)

plt.title("Marital Status percentage")
plt.xlabel("Marital Status")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)

plt.show()
# Out:
# Marital Status count:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64
#
# Marital Status percentage:
# Marital Status
# Single               69.07
# Married              27.84
# Prefer not to say     3.09
# Name: count, dtype: float64

# %%
occupation_counts = df["Occupation"].value_counts()
occupation_percentage = (occupation_counts / occupation_counts.sum() * 100).round(2)
print("Occupation count:")
print(occupation_counts)
print("\nOccupation percentage:")
print(occupation_percentage)
occupation_percentage.plot(kind="bar", color=["blue", "green", "grey"], width=0.2)

plt.title("Occupation percentage")
plt.xlabel("Occupation")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0) 

plt.show()
# Out:
# Occupation count:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64
#
# Occupation percentage:
# Occupation
# Student           53.35
# Employee          30.41
# Self Employeed    13.92
# House wife         2.32
# Name: count, dtype: float64

# %%
monthly_income = df["Monthly Income"].value_counts()
monthly_income_percentage = (monthly_income / monthly_income.sum() * 100).round(2)

print("Monthly Income count:")
print(monthly_income)

print("\nMonthly Income percentage:")
print(monthly_income_percentage)

new_labels = [label.replace(" ", "\n") for label in monthly_income.index]
unique_categories = monthly_income.index.nunique()
colors = plt.cm.viridis(np.linspace(0, 1, unique_categories))

monthly_income_percentage.plot(kind="bar", color=colors, width=0.2)

plt.title("Monthly Income percentage")
plt.xlabel("Monthly Income")
plt.ylabel("Percentage (%)")
plt.xticks(range(len(new_labels)), new_labels, rotation=45)
plt.tight_layout()

plt.show()
# Out:
# Monthly Income count:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64
#
# Monthly Income percentage:
# Monthly Income
# No Income          48.20
# 25001 to 50000     17.78
# More than 50000    15.98
# 10001 to 25000     11.60
# Below Rs.10000      6.44
# Name: count, dtype: float64

# %%
educational_qualifications = df["Educational Qualifications"].value_counts()
educational_qualifications_percentage = (educational_qualifications / educational_qualifications.sum() * 100).round(2)

print("Educational Qualifications count:")
print(educational_qualifications)

print("\nEducational Qualifications percentage:")
print(educational_qualifications_percentage)

new_labels = [label.replace(" ", "\n") for label in educational_qualifications.index]
unique_categories = educational_qualifications.index.nunique()
colors = plt.cm.viridis(np.linspace(0, 1, unique_categories))

educational_qualifications_percentage.plot(kind="bar", color=colors, width=0.2)

plt.title("Educational Qualifications percentage")
plt.xlabel("Educational Qualifications")
plt.ylabel("Percentage (%)")
plt.xticks(range(len(new_labels)), new_labels, rotation=45)
plt.tight_layout()

plt.show()
# Out:
# Educational Qualifications count:
# Educational Qualifications
# Graduate         177
# Post Graduate    174
# Ph.D              23
# School            12
# Uneducated         2
# Name: count, dtype: int64
#
# Educational Qualifications percentage:
# Educational Qualifications
# Graduate         45.62
# Post Graduate    44.85
# Ph.D              5.93
# School            3.09
# Uneducated        0.52
# Name: count, dtype: float64

# %%
family_size = df["Family size"].value_counts()
family_size_percentage = (family_size / family_size.sum() * 100).round(2)

print("Family size count:")
print(family_size)

print("\nFamily size percentage:")
print(family_size_percentage)

unique_categories = family_size.index.nunique()
colors = plt.cm.viridis(np.linspace(0, 1, unique_categories))

family_size_percentage.plot(kind="bar", color=colors, width=0.2)

plt.title("Family size percentage")
plt.xlabel("Family size")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0) 

plt.tight_layout()

plt.show()
# Out:
# Family size count:
# Family size
# 3    117
# 2    101
# 4     63
# 5     54
# 6     29
# 1     24
# Name: count, dtype: int64
#
# Family size percentage:
# Family size
# 3    30.15
# 2    26.03
# 4    16.24
# 5    13.92
# 6     7.47
# 1     6.19
# Name: count, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["latitude"], bins=20, color="skyblue", edgecolor="black")

plt.title("Latitude Distribution")
plt.xlabel("Latitude")
plt.ylabel("Frequency")

# Mostrar o gráfico
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["longitude"], bins=20, color="skyblue", edgecolor="black")

# Adicionar título e rótulos aos eixos
plt.title("Longitude Distribution")
plt.xlabel("Latitude")
plt.ylabel("Frequency")

# Mostrar o gráfico
plt.tight_layout()
plt.show()

# %%
feedback = df["Feedback"].value_counts()
feedback_percentage = (feedback / feedback.sum() * 100).round(2)

print("Feedback count:")
print(feedback)

print("\Feedback percentage:")
print(feedback_percentage)

plt.figure(figsize=(8, 8))
plt.pie(feedback, labels=feedback.index, autopct="%1.1f%%", startangle=140, colors=["lightblue", "red"])
plt.title("Positive vs Negative Feedback Ratio")

# Desenhar um círculo no meio para transformá-lo em um gráfico de rosca
centre_circle = plt.Circle((0,0),0.70,fc="white")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.show()
# Out:
# Feedback count:
# Feedback
# Positive     317
# Negative      71
# Name: count, dtype: int64
# \Feedback percentage:
# Feedback
# Positive     81.7
# Negative     18.3
# Name: count, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black")

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Gender", hue="Feedback")

plt.title("Feedback Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Occupation", hue="Feedback")

plt.title("Feedback Distribution by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
# %pip install seaborn

import seaborn as sns
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.7 MB/s eta 0:00:005.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
import seaborn as sns
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.3 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
numeric_df = df.select_dtypes(include=[np.number])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="Reds")
plt.title("Correlation heatmap")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Gender", y="Age", data=df, hue="Gender", palette={"Male": "lightblue", "Female": "pink"})
plt.title("Age Distribution by Gender")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Monthly Income", hue="Feedback")

plt.title("Feedback Distribution by Monthly Income")
plt.xlabel("Monthly Income")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Marital Status", hue="Feedback")

plt.title("Feedback Distribution by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))
order = ["Uneducated", "School", "Graduate", "Post Graduate", "Ph.D"]
sns.countplot(data=df, x="Educational Qualifications", hue="Monthly Income", order=order)

plt.title("Feedback Distribution by Educational Qualifications")
plt.xlabel("Educational Qualifications")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
# %pip install plotly
import plotly.express as px
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 8.8 MB/s eta 0:00:000m eta 0:00:0136m0:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x="Gender", hue="Monthly Income")

plt.title("Monthly Income by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x="Occupation", hue="Monthly Income")

plt.title("Monthly Income by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x="Family size", hue="Monthly Income")

plt.title("Monthly Income by Family size")
plt.xlabel("Family size")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x="Feedback", hue="Monthly Income")

plt.title("Monthly Income by Feedback")
plt.xlabel("Feedback")
plt.ylabel("Count")
plt.legend(title="Feedback")

plt.show()
